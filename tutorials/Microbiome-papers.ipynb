# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [微生物组研究方法](#toc1_)
#   - 1.1. [扩增子](#toc1_1_)
#   - 1.2. [宏基因组](#toc1_2_)
# - 2. [生态学](#toc2_)
# - 3. [医学微生态](#toc3_)
# - 4. [动物微生态](#toc4_)
# - 5. [植物微生态](#toc5_)
# - 6. [附录](#toc6_)
#   - 6.1. [生成README.md](#toc6_1_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # 1. <a id='toc1_'></a>[微生物组研究方法](#toc0_)

# %% [markdown]
# ## 1.1. <a id='toc1_1_'></a>[扩增子](#toc0_)

# %% [markdown]
# - [EasyAmplicon: An easy‐to‐use, open‐source, reproducible, and community‐based pipeline for amplicon data analysis in microbiome research](https://doi.org/10.1002/imt2.83)

# %% [markdown]
# ## 1.2. <a id='toc1_2_'></a>[宏基因组](#toc0_)

# %% [markdown]
# - [EasyMetagenome: A user-friendly and flexible pipeline for shotgun metagenomic analysis in microbiome research](https://doi.org/10.1002/imt2.70001)

# %% [markdown]
# # 2. <a id='toc2_'></a>[生态学](#toc0_)

# %% [markdown]
# - [Microbial generalists and specialists differently contribute to the community diversity in farmland soils](https://doi.org/10.1016/j.jare.2021.12.003)

# %% [markdown]
# # 3. <a id='toc3_'></a>[医学微生态](#toc0_)

# %% [markdown]
# - [Distinct intestinal microbial signatures linked to accelerated systemic and intestinal biological aging](https://doi.org/10.1186/s40168-024-01758-4)

# %% [markdown]
# # 4. <a id='toc4_'></a>[动物微生态](#toc0_)

# %% [markdown]
# - [Clostridium butyricum and carbohydrate active enzymes contribute to the reduced fat deposition in pigs](https://doi.org/10.1002/imt2.160)

# %% [markdown]
# # 5. <a id='toc5_'></a>[植物微生态](#toc0_)

# %% [markdown]
# - [Root microbiota regulates tiller number in rice](https://doi.org/10.1016/j.cell.2025.03.033)

# %% [markdown]
# # 6. <a id='toc6_'></a>[附录](#toc0_)

# %% [markdown]
# ## 6.1. <a id='toc6_1_'></a>[生成README.md](#toc0_)

# %%
import json


def ipynb2(ipynb_file:str, label:str, output_file:str) -> None:
    '''
    Collect code blocks started with label, such as "#@save" in ipynb format file to one file named with outputfile.
    Args:
        ipynb_file: str
        label: str, such as %%bash, #@save and etc.
        output_file: str
    
    # Demo:
    >>> extract_save_blocks(ipynb_file= 'learn_PyTorch.ipynb', label= '#@save', output_file= 'utils/utils.py')
    '''
    # text = '''
    # # This file is generated from saved notebook code blocks
    # '''
    text = '''
    # Author: Yu Zhao
    # Copyright (c) 2025 Yu Zhao
    '''
    
    with open(ipynb_file, 'r', encoding='utf-8') as f:
        notebook = json.load(f)

    saved_code_blocks = []

    for cell in notebook.get('cells', []):
        if cell.get('cell_type') == 'code':
            source_lines = cell.get('source', [])
            if source_lines and source_lines[0].lstrip().startswith(label):
                code_block = ''.join(source_lines)
                saved_code_blocks.append(code_block)

    if saved_code_blocks:
        with open(output_file, 'w', encoding='utf-8') as f_out:
            f_out.write(f"{text}")
            f_out.write("\n\n")
            f_out.write("\n\n\n".join(saved_code_blocks))
        print(f"Saved {len(saved_code_blocks)} block(s) to {output_file}")
    else:
        print(f"No {label} blocks found.")


# 生成README.md
# ipynb2('Microbiome papers.ipynb', '#@save', 'README.md')
